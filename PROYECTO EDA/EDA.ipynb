# %% [markdown]
# **TITULO**: Comprar mi primera casa: ¿dónde puedo vivir con 80.000€ en España?

# %% [markdown]
# **TEMA**: Este análisis busca determinar en qué comunidades autónomas y provincias de España se pueden adquirir viviendas por un precio igual o inferior a 80.000 euros. Se analizarán diferencias geográficas, tipos de vivienda, tamaño y estado, con el objetivo de evaluar la viabilidad de acceder a una primera vivienda con un presupuesto limitado. Para este estudio tendremos en cuenta unicamenta los datos del 2024.

# %% [markdown]
# **HIPOTESIS PRINCIPAL**: Con un presupuesto de 80.000€, no es posible comprar una vivienda en la ciudad de Madrid, pero si en otras provincias de España.

# %% [markdown]
# **Subhipotesis 1**: En las provincias del interior (no capitalinas) hay mayor proporción de viviendas disponibles por menos de 80.000€.
#
# **Subhipotesis 2**: Las viviendas dentro del presupuesto tienen menor superficie media que las de mayor precio.
#
# **Subhipotesis 3**: Hay diferencias significativas entre comunidades en la cantidad de viviendas por debajo de ese presupuesto.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

INE_2024 = pd.read_csv( 'img/INE.csv', sep= ';', encoding='UTF-8')

# %%
INE_2024
# Out:
#       Total Nacional Comunidades y Ciudades Autónomas  \
# 0           Nacional                              NaN
# 1           Nacional                              NaN
# 2           Nacional                              NaN
# 3           Nacional                              NaN
# 4           Nacional                              NaN
# ...              ...                              ...
# 17515       Nacional                       19 Melilla
# 17516       Nacional                       19 Melilla
# 17517       Nacional                       19 Melilla
# 17518       Nacional                       19 Melilla
# 17519       Nacional                       19 Melilla
#
#       General, vivienda nueva y de segunda mano  \
# 0                                       General
# 1                                       General
# 2                                       General
# 3                                       General
# 4                                       General
# ...
